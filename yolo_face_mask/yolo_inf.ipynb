# %% [markdown]
# Untuk melakukan inference, bisa dilakukan dengan weights yang sudah di simpan dalam bentuk tensorflow, atau dengan menggunakan file weights .pt yang sudah didapat dari hasil model train.

# %%
#import tensorflow as tf
#new_model = tf.keras.models.load_model(r'weights\best_saved_model')
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# WARNING:absl:Importing a function (__inference_pruned_7755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.

# %% [markdown]
# Clone repository `https://github.com/ultralytics/yolov5` dan install libraries dari *requirements.txt*.

# %%
# !git clone https://github.com/ultralytics/yolov5
# !pip install -qr yolov5/requirements.txt
# Out:
# Cloning into 'yolov5'...
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %% [markdown]
# Jalankan code berikut dan masukkan path image untuk mendeteksi mask object pada image tersebut.
# !python path/detect.py -- --source (image path) --weight (model path) --data (path yaml data file) --name (folder file name) --conf (conf).

# %% [markdown]
# Output model akan ada di yolov5/runs/detect . Bisa diubah di pengaturan file detect.py

# %%
# !python yolov5/detect.py --source people_bicycles.jpg --weight weights/best_saved_model --data yolov5/data/data.yaml --conf 0.4
# Out:
# detect: weights=['weights/best_saved_model'], source=people_bicycles.jpg, data=yolov5/data/data.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'E:\KULIAH\study': No such file or directory
# YOLOv5  2022-9-22 Python-3.8.13 torch-1.11.0+cpu CPU
#
# Loading weights\best_saved_model for TensorFlow SavedModel inference...
# 2022-09-26 16:12:03.809740: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# ...

# %%
from PIL import Image
Image.open(r'yolov5\runs\detect\people_bicycles.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600>

# %% [markdown]
# Untuk mendeteksi object dengan webcam, set source value menjadi 0 sebagai berikut. Tampilan webcam akan otomatis keluar.
#
# Untuk menutup tampilan webcam tekan 'q' dua kali.

# %%
#uncomment to use webcam

#!python yolov5/detect.py --source 0 --weight weights/best_saved_model --data yolov5/data/data.yaml --conf 0.4
# Out:
# detect: weights=['weights/best_saved_model'], source=0, data=yolov5/data/data.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'E:\KULIAH\study': No such file or directory
# YOLOv5  2022-9-22 Python-3.8.13 torch-1.11.0+cpu CPU
#
# Loading weights\best_saved_model for TensorFlow SavedModel inference...
# 2022-09-26 16:09:06.966167: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# ...
